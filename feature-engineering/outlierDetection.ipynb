# %% [markdown]
# ### 5  NUMBER SUMMARY AND BOX PLOT

# %%
## Minimum,Maximum,Median,Q1,Q3,IQR

# %%
import numpy as np

# %%
lst_mark=[45,32,56,75,89,54,32,89,90,87,60,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(lst_mark,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1 - 1.5*(IQR)
higher_fence = Q3 + 1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(1.5)

# %%
higher_fence
# Out:
# np.float64(141.5)

# %%
 lst_mark=[45,32,56,75,89,54,32,89,90,87,60,54,45,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_mark)
# Out:
# <Axes: >

# %%
lst_mark1=[-100,-200,45,32,56,75,89,54,32,89,90,87,60,54,45,98,99,67,74,200,170,180]

# %%
sns.boxplot(lst_mark1)
# Out:
# <Axes: >

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")

clean_data = [x for x in lst_mark1 if lower_bound <= x <= upper_bound]
print(f"Original: {lst_mark1}")
print(f"After removing outliers: {clean_data}")
# Out:
# Lower Bound: 1.5
# Upper Bound: 141.5
# Original: [-100, -200, 45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 60, 54, 45, 98, 99, 67, 74, 200, 170, 180]
# After removing outliers: [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 60, 54, 45, 98, 99, 67, 74]
